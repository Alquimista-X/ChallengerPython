# %% [markdown]
# <a href="https://colab.research.google.com/github/Alquimista-X/ChallengerPython/blob/main/Challenge_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd #El código extrae información de las cuatro tiendas y organiza los datos en DataFrames utilizando la biblioteca Pandas.

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
Tiendas = [tienda,tienda2,tienda3,tienda4]
TiendaName = ["Tienda1","Tienda2","Tienda3","Tienda4"]
Rentabilidad = {(TiendaName[i]):(sum(Tiendas[i]["Precio"])/sum(Tiendas[i]["Costo de envío"])) for i in range(0,4) if (Tiendas[i]["Cantidad de cuotas"] == 1).any()}
Rentabilidad
# Out:
# {'Tienda1': 18.75072949709912,
#  'Tienda2': 18.76677520925408,
#  'Tienda3': 18.764241258036183,
#  'Tienda4': 18.771231113537514}

# %% [markdown]
# #1. Análisis de facturación

# %%
from matplotlib import pyplot as plt

# %%
SumaVentas1 = sum(tienda['Precio'])
SumaVentas2 = sum(tienda2['Precio'])
SumaVentas3 = sum(tienda3['Precio'])
SumaVentas4 = sum(tienda4['Precio'])
Tiendas = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
Ventas = [SumaVentas1,SumaVentas2,SumaVentas3,SumaVentas4]
TiendaVentas = list(zip(Tiendas,Ventas))
plt.bar(x= Tiendas, height=Ventas)
plt.title("Ventas por tienda")
plt.show()
TiendaVentas
# Out:
# [('Tienda 1', 1150880400.0),
#  ('Tienda 2', 1116343500.0),
#  ('Tienda 3', 1098019600.0),
#  ('Tienda 4', 1038375700.0)]

# %% [markdown]
# # 2. Ventas por categoría

# %%
#Categorias = ["Electronicos","Muebles","Juguetes","Electrodomesticos","Deportes y diversión","Libros","Artí­culos para el hogar"]
#VentasElectron = sum(tienda["Categoría del Producto"] == "Electrónicos")
#VentasElectron2 = sum(tienda2["Categoría del Producto"] == "Electrónicos")
#VentasElectron3 = sum(tienda3["Categoría del Producto"] == "Electrónicos")
#VentasElectron4 = sum(tienda4["Categoría del Producto"] == "Electrónicos")
#VentasElectronicos = [VentasElectron,VentasElectron2,VentasElectron3,VentasElectron4]
#VentasElectronicos

# %%
Tiendas = [tienda,tienda2,tienda3,tienda4] #Se listan las tiendas que representan a cada uno de los archivos.csv
CategoriasGeneral = pd.concat([tienda['Categoría del Producto'],tienda2['Categoría del Producto'],tienda3['Categoría del Producto'],tienda4['Categoría del Producto']])
Categorias = CategoriasGeneral.unique()
#Categorias = ["Electrónicos","Muebles","Juguetes","Electrodomésticos","Deportes y diversión","Libros","Artículos para el hogar"] #Se listan las categorias que queremos calcular, colocando los nombres tal cual esta en los archivos
VentasPorCategoria = {(categoria): sum(Tiendas[0]["Categoría del Producto"] == categoria) for categoria in Categorias} #
valores = list(VentasPorCategoria.values())
etiquetas = list(VentasPorCategoria.keys())
plt.pie(valores, labels=etiquetas, autopct="%1.1f%%")
plt.title("Cantidad de ventas por categoria - Tienda 1")
plt.show()
VentasPorCategoria
# Out:
# {'Electrónicos': 448,
#  'Muebles': 465,
#  'Juguetes': 324,
#  'Electrodomésticos': 312,
#  'Artículos para el hogar': 171,
#  'Deportes y diversión': 284,
#  'Libros': 173,
#  'Instrumentos musicales': 182}

# %%
Tiendas = [tienda,tienda2,tienda3,tienda4]
CategoriasGeneral = pd.concat([tienda['Categoría del Producto'],tienda2['Categoría del Producto'],tienda3['Categoría del Producto'],tienda4['Categoría del Producto']])
Categorias = CategoriasGeneral.unique()
#Categorias = ["Electrónicos","Muebles","Juguetes","Electrodomésticos","Deportes y diversión","Libros","Artículos para el hogar"]
VentasPorCategoria = {(categoria): sum(Tiendas[1]["Categoría del Producto"] == categoria) for categoria in Categorias}
valores = list(VentasPorCategoria.values())
etiquetas = list(VentasPorCategoria.keys())
plt.pie(valores, labels=etiquetas, autopct="%1.1f%%")
plt.title("Cantidad de ventas por categoria - Tienda 2")
plt.show()
VentasPorCategoria
# Out:
# {'Electrónicos': 422,
#  'Muebles': 442,
#  'Juguetes': 313,
#  'Electrodomésticos': 305,
#  'Artículos para el hogar': 181,
#  'Deportes y diversión': 275,
#  'Libros': 197,
#  'Instrumentos musicales': 224}

# %%
Tiendas = [tienda,tienda2,tienda3,tienda4]
#Categorias = ["Electrónicos","Muebles","Juguetes","Electrodomésticos","Deportes y diversión","Libros","Artículos para el hogar"]
CategoriasGeneral = pd.concat([tienda['Categoría del Producto'],tienda2['Categoría del Producto'],tienda3['Categoría del Producto'],tienda4['Categoría del Producto']])
Categorias = CategoriasGeneral.unique()
VentasPorCategoria = {(categoria): sum(Tiendas[2]["Categoría del Producto"] == categoria) for categoria in Categorias}
valores = list(VentasPorCategoria.values())
etiquetas = list(VentasPorCategoria.keys())
plt.pie(valores, labels=etiquetas, autopct="%1.1f%%")
plt.title("Cantidad de ventas por categoria - Tienda 3")
plt.show()
VentasPorCategoria
# Out:
# {'Electrónicos': 451,
#  'Muebles': 499,
#  'Juguetes': 315,
#  'Electrodomésticos': 278,
#  'Artículos para el hogar': 177,
#  'Deportes y diversión': 277,
#  'Libros': 185,
#  'Instrumentos musicales': 177}

# %%
Tiendas = [tienda,tienda2,tienda3,tienda4]
CategoriasGeneral = pd.concat([tienda['Categoría del Producto'],tienda2['Categoría del Producto'],tienda3['Categoría del Producto'],tienda4['Categoría del Producto']])
Categorias = CategoriasGeneral.unique()
#Categorias = ["Electrónicos","Muebles","Juguetes","Electrodomésticos","Deportes y diversión","Libros","Artículos para el hogar"]
VentasPorCategoria = {(categoria): sum(Tiendas[3]["Categoría del Producto"] == categoria) for categoria in Categorias}
valores = list(VentasPorCategoria.values())
etiquetas = list(VentasPorCategoria.keys())
plt.pie(valores, labels=etiquetas, autopct="%1.1f%%")
plt.title("Cantidad de ventas por categoria - Tienda 4")
plt.show()
VentasPorCategoria
# Out:
# {'Electrónicos': 451,
#  'Muebles': 480,
#  'Juguetes': 338,
#  'Electrodomésticos': 254,
#  'Artículos para el hogar': 201,
#  'Deportes y diversión': 277,
#  'Libros': 187,
#  'Instrumentos musicales': 170}

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
Tiendas = [tienda,tienda2,tienda3,tienda4]
TiendasName = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
PromedioCalificación = {TiendasName[i]:sum(Tiendas[i]["Calificación"])/len(Tiendas[i]["Calificación"]) for i in range(0,4)}
valores = list(PromedioCalificación.values())
etiquetas = list(PromedioCalificación.keys())
plt.bar(x= etiquetas, height=valores)
plt.title("Calificación promedio de las tiendas")
plt.show()
PromedioCalificación
# Out:
# {'Tienda 1': 3.976685036032217,
#  'Tienda 2': 4.037303942348453,
#  'Tienda 3': 4.048325561678677,
#  'Tienda 4': 3.9957591178965224}

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
#Tiendas = [tienda,tienda2,tienda3,tienda4]
#TiendasName = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
#ProductosVendidos = pd.concat([tienda['Producto'],tienda2['Producto'],tienda3['Producto'],tienda4['Producto']])
#Productos = ProductosVendidos.unique()
#ProductosTienda = {(TiendasName[i],producto): sum(Tiendas[i]["Producto"] == producto) for producto in Productos for i in range(0,4)}
#ProductosMax = max(ProductosTienda.values())
#ProductosMin = min(ProductosTienda.values())
#ProductosMasVendido = [(product,cantidad) for product,cantidad in ProductosTienda.items() if cantidad == ProductosMax]
#ProductosMenosVendido = [(product,cantidad) for product,cantidad in ProductosTienda.items() if cantidad == ProductosMin]
#ProductosTienda

# %%
TiendasName = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
ProductosVendidos = pd.concat([tienda['Producto'],tienda2['Producto'],tienda3['Producto'],tienda4['Producto']])
Productos = ProductosVendidos.unique()
ProductosTienda = {(TiendasName[i],producto): sum(Tiendas[i]["Producto"] == producto) for producto in Productos for i in range(0,4)}

listaGeneral = list(ProductosTienda.items())
lista1 = listaGeneral[0::4]
lista2 = listaGeneral[1::4]
lista3 = listaGeneral[2::4]
lista4 = listaGeneral[3::4]

ProductosMaxTienda1 = max([valor[1] for valor in lista1])
ProductosMinTienda1 = min([valor[1] for valor in lista1])
ProductosMasVendidoTienda1 = [(product,cantidad) for product,cantidad in lista1 if cantidad == ProductosMaxTienda1]
ProductosMenosVendidoTienda1 = [(product,cantidad) for product,cantidad in lista1 if cantidad == ProductosMinTienda1]

ProductosMaxTienda2 = max([valor[1] for valor in lista2])
ProductosMinTienda2 = min([valor[1] for valor in lista2])
ProductosMasVendidoTienda2 = [(product,cantidad) for product,cantidad in lista2 if cantidad == ProductosMaxTienda2]
ProductosMenosVendidoTienda2 = [(product,cantidad) for product,cantidad in lista2 if cantidad == ProductosMinTienda2]

ProductosMaxTienda3 = max([valor[1] for valor in lista3])
ProductosMinTienda3 = min([valor[1] for valor in lista3])
ProductosMasVendidoTienda3 = [(product,cantidad) for product,cantidad in lista3 if cantidad == ProductosMaxTienda3]
ProductosMenosVendidoTienda3 = [(product,cantidad) for product,cantidad in lista3 if cantidad == ProductosMinTienda3]

ProductosMaxTienda4 = max([valor[1] for valor in lista4])
ProductosMinTienda4 = min([valor[1] for valor in lista4])
ProductosMasVendidoTienda4 = [(product,cantidad) for product,cantidad in lista4 if cantidad == ProductosMaxTienda4]
ProductosMenosVendidoTienda4 = [(product,cantidad) for product,cantidad in lista4 if cantidad == ProductosMinTienda4]


print(f"Los productos mas vendidos de la Tienda 1 son: {ProductosMasVendidoTienda1}\n y los productos menos vendidos de la Tienda 1 son: {ProductosMenosVendidoTienda1}\n\nLos productos mas vendidos de la Tienda 2 son: {ProductosMasVendidoTienda2}\n y los productos menos vendidos de la Tienda 2 son: {ProductosMenosVendidoTienda2}\n\nLos productos mas vendidos de la Tienda 3 son: {ProductosMasVendidoTienda3}\n y los productos menos vendidos de la Tienda 3 son: {ProductosMenosVendidoTienda3}\n\nLos productos mas vendidos de la Tienda 4 son: {ProductosMasVendidoTienda4}\n y los productos menos vendidos de la Tienda 4 son: {ProductosMenosVendidoTienda4}")
# Out:
# Los productos mas vendidos de la Tienda 1 son: [(('Tienda 1', 'Microondas'), 60), (('Tienda 1', 'TV LED UHD 4K'), 60), (('Tienda 1', 'Armario'), 60)]
#  y los productos menos vendidos de la Tienda 1 son: [(('Tienda 1', 'Auriculares con micrófono'), 33), (('Tienda 1', 'Celular ABXY'), 33)]
#
# Los productos mas vendidos de la Tienda 2 son: [(('Tienda 2', 'Iniciando en programación'), 65)]
#  y los productos menos vendidos de la Tienda 2 son: [(('Tienda 2', 'Juego de mesa'), 32)]
#
# Los productos mas vendidos de la Tienda 3 son: [(('Tienda 3', 'Kit de bancas'), 57)]
#  y los productos menos vendidos de la Tienda 3 son: [(('Tienda 3', 'Bloques de construcción'), 35)]
#
# Los productos mas vendidos de la Tienda 4 son: [(('Tienda 4', 'Cama box'), 62)]
#  y los productos menos vendidos de la Tienda 4 son: [(('Tienda 4', 'Guitarra eléctrica'), 33)]

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
Tiendas = [tienda,tienda2,tienda3,tienda4]
TiendasName = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
PromedioEnvio = {TiendasName[i]:sum(Tiendas[i]["Costo de envío"])/len(Tiendas[i]["Costo de envío"]) for i in range(0,4)}
valores = list(PromedioEnvio.values())
etiquetas = list(PromedioEnvio.keys())
plt.figure(figsize=(8, 5))

bars = plt.barh(etiquetas, valores, color='skyblue')
plt.title("Promedio de Costo de Envío por Tienda", fontweight='bold')
plt.xlabel("Costo Promedio ($)", fontsize=12)
plt.ylabel("Tiendas", fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.5,  # Posición X (ancho de la barra + margen)
             bar.get_y() + bar.get_height()/2,  # Posición Y (centro de la barra)
             f"${width:.2f}",  # Texto (formateado a 2 decimales)
             va='center', ha='left', fontweight='bold')

plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd #El código extrae información de las cuatro tiendas y organiza los datos en DataFrames utilizando la biblioteca Pandas.

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

def AnalisisFacturacion():
    SumaVentas1 = sum(tienda['Precio'])
    SumaVentas2 = sum(tienda2['Precio'])
    SumaVentas3 = sum(tienda3['Precio'])
    SumaVentas4 = sum(tienda4['Precio'])
    Tiendas = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
    Ventas = [SumaVentas1,SumaVentas2,SumaVentas3,SumaVentas4]
    TiendaVentas = list(zip(Tiendas,Ventas))
    plt.bar(x= Tiendas, height=Ventas)
    plt.title("Ventas por tienda")
    for i, v in enumerate(Ventas):
        plt.text(i, v, f"${v:,.2f}", ha='center', va='bottom', fontweight='bold')
    plt.show()

def VentasPorCategoria1():
    Tiendas = [tienda,tienda2,tienda3,tienda4] #Se listan las tiendas que representan a cada uno de los archivos.csv
    CategoriasGeneral = pd.concat([tienda['Categoría del Producto'],tienda2['Categoría del Producto'],tienda3['Categoría del Producto'],tienda4['Categoría del Producto']])
    Categorias = CategoriasGeneral.unique()
    #Categorias = ["Electrónicos","Muebles","Juguetes","Electrodomésticos","Deportes y diversión","Libros","Artículos para el hogar"] #Se listan las categorias que queremos calcular, colocando los nombres tal cual esta en los archivos
    VentasPorCategoria = {(categoria): sum(Tiendas[0]["Categoría del Producto"] == categoria) for categoria in Categorias} #
    valores = list(VentasPorCategoria.values())
    etiquetas = list(VentasPorCategoria.keys())
    def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{v:d}\n({p:.1f}%)'.format(p=pct, v=val)
        return my_format

    # Crear el gráfico de pie
    plt.figure(figsize=(6, 4))
    plt.pie(valores, labels=etiquetas, autopct=autopct_format(valores), startangle=90)
    plt.title("Cantidad de ventas por categoría - Tienda 1")
    plt.axis('equal')
    plt.show()


def VentasPorCategoria2():
    Tiendas = [tienda,tienda2,tienda3,tienda4]
    CategoriasGeneral = pd.concat([tienda['Categoría del Producto'],tienda2['Categoría del Producto'],tienda3['Categoría del Producto'],tienda4['Categoría del Producto']])
    Categorias = CategoriasGeneral.unique()
    #Categorias = ["Electrónicos","Muebles","Juguetes","Electrodomésticos","Deportes y diversión","Libros","Artículos para el hogar"]
    VentasPorCategoria = {(categoria): sum(Tiendas[1]["Categoría del Producto"] == categoria) for categoria in Categorias}
    valores = list(VentasPorCategoria.values())
    etiquetas = list(VentasPorCategoria.keys())
    def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{v:d}\n({p:.1f}%)'.format(p=pct, v=val)
        return my_format
    plt.figure(figsize=(6, 4))
    plt.pie(valores, labels=etiquetas, autopct=autopct_format(valores), startangle=90)
    plt.title("Cantidad de ventas por categoría - Tienda 2")
    plt.axis('equal')
    plt.show()



def VentasPorCategoria3():
    Tiendas = [tienda,tienda2,tienda3,tienda4]
    #Categorias = ["Electrónicos","Muebles","Juguetes","Electrodomésticos","Deportes y diversión","Libros","Artículos para el hogar"]
    CategoriasGeneral = pd.concat([tienda['Categoría del Producto'],tienda2['Categoría del Producto'],tienda3['Categoría del Producto'],tienda4['Categoría del Producto']])
    Categorias = CategoriasGeneral.unique()
    VentasPorCategoria = {(categoria): sum(Tiendas[2]["Categoría del Producto"] == categoria) for categoria in Categorias}
    valores = list(VentasPorCategoria.values())
    etiquetas = list(VentasPorCategoria.keys())
    def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{v:d}\n({p:.1f}%)'.format(p=pct, v=val)
        return my_format
    plt.figure(figsize=(6, 4))
    plt.pie(valores, labels=etiquetas, autopct=autopct_format(valores), startangle=90)
    plt.title("Cantidad de ventas por categoría - Tienda 3")
    plt.axis('equal')
    plt.show()



def VentasPorCategoria4():
    Tiendas = [tienda,tienda2,tienda3,tienda4]
    CategoriasGeneral = pd.concat([tienda['Categoría del Producto'],tienda2['Categoría del Producto'],tienda3['Categoría del Producto'],tienda4['Categoría del Producto']])
    Categorias = CategoriasGeneral.unique()
    #Categorias = ["Electrónicos","Muebles","Juguetes","Electrodomésticos","Deportes y diversión","Libros","Artículos para el hogar"]
    VentasPorCategoria = {(categoria): sum(Tiendas[3]["Categoría del Producto"] == categoria) for categoria in Categorias}
    valores = list(VentasPorCategoria.values())
    etiquetas = list(VentasPorCategoria.keys())
    def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{v:d}\n({p:.1f}%)'.format(p=pct, v=val)
        return my_format

    # Crear el gráfico de pie
    plt.figure(figsize=(6, 4))
    plt.pie(valores, labels=etiquetas, autopct=autopct_format(valores), startangle=90)
    plt.title("Cantidad de ventas por categoría - Tienda 4")
    plt.axis('equal')
    plt.show()

def CalificacionTienda():
    Tiendas = [tienda,tienda2,tienda3,tienda4]
    TiendasName = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
    PromedioCalificación = {TiendasName[i]:sum(Tiendas[i]["Calificación"])/len(Tiendas[i]["Calificación"]) for i in range(0,4)}
    valores = list(PromedioCalificación.values())
    etiquetas = list(PromedioCalificación.keys())
    plt.figure(figsize=(6, 4))
    bars = plt.bar(x=etiquetas, height=valores)

    # Añadir los valores encima de cada barra
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                 f'{height:.2f}',  # Formato con 2 decimales
                 ha='center', va='bottom')

    plt.title("Calificación promedio de las tiendas")
    plt.ylabel("Promedio de calificación")
    plt.ylim(0, max(valores) * 1.1)  # Dejar espacio para las etiquetas
    plt.show()

def ProductoVendidos():
    TiendasName = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
    ProductosVendidos = pd.concat([tienda['Producto'],tienda2['Producto'],tienda3['Producto'],tienda4['Producto']])
    Productos = ProductosVendidos.unique()
    ProductosTienda = {(TiendasName[i],producto): sum(Tiendas[i]["Producto"] == producto) for producto in Productos for i in range(0,4)}

    listaGeneral = list(ProductosTienda.items())
    lista1 = listaGeneral[0::4]
    lista2 = listaGeneral[1::4]
    lista3 = listaGeneral[2::4]
    lista4 = listaGeneral[3::4]

    ProductosMaxTienda1 = max([valor[1] for valor in lista1])
    ProductosMinTienda1 = min([valor[1] for valor in lista1])
    ProductosMasVendidoTienda1 = [(product,cantidad) for product,cantidad in lista1 if cantidad == ProductosMaxTienda1]
    ProductosMenosVendidoTienda1 = [(product,cantidad) for product,cantidad in lista1 if cantidad == ProductosMinTienda1]

    ProductosMaxTienda2 = max([valor[1] for valor in lista2])
    ProductosMinTienda2 = min([valor[1] for valor in lista2])
    ProductosMasVendidoTienda2 = [(product,cantidad) for product,cantidad in lista2 if cantidad == ProductosMaxTienda2]
    ProductosMenosVendidoTienda2 = [(product,cantidad) for product,cantidad in lista2 if cantidad == ProductosMinTienda2]

    ProductosMaxTienda3 = max([valor[1] for valor in lista3])
    ProductosMinTienda3 = min([valor[1] for valor in lista3])
    ProductosMasVendidoTienda3 = [(product,cantidad) for product,cantidad in lista3 if cantidad == ProductosMaxTienda3]
    ProductosMenosVendidoTienda3 = [(product,cantidad) for product,cantidad in lista3 if cantidad == ProductosMinTienda3]

    ProductosMaxTienda4 = max([valor[1] for valor in lista4])
    ProductosMinTienda4 = min([valor[1] for valor in lista4])
    ProductosMasVendidoTienda4 = [(product,cantidad) for product,cantidad in lista4 if cantidad == ProductosMaxTienda4]
    ProductosMenosVendidoTienda4 = [(product,cantidad) for product,cantidad in lista4 if cantidad == ProductosMinTienda4]


    print(f"Los productos mas vendidos de la Tienda 1 son: {ProductosMasVendidoTienda1}\n y los productos menos vendidos de la Tienda 1 son: {ProductosMenosVendidoTienda1}\n\nLos productos mas vendidos de la Tienda 2 son: {ProductosMasVendidoTienda2}\n y los productos menos vendidos de la Tienda 2 son: {ProductosMenosVendidoTienda2}\n\nLos productos mas vendidos de la Tienda 3 son: {ProductosMasVendidoTienda3}\n y los productos menos vendidos de la Tienda 3 son: {ProductosMenosVendidoTienda3}\n\nLos productos mas vendidos de la Tienda 4 son: {ProductosMasVendidoTienda4}\n y los productos menos vendidos de la Tienda 4 son: {ProductosMenosVendidoTienda4}")

def EnvioTienda():
    Tiendas = [tienda,tienda2,tienda3,tienda4]
    TiendasName = ["Tienda 1","Tienda 2","Tienda 3","Tienda 4"]
    PromedioEnvio = {TiendasName[i]:sum(Tiendas[i]["Costo de envío"])/len(Tiendas[i]["Costo de envío"]) for i in range(0,4)}
    valores = list(PromedioEnvio.values())
    etiquetas = list(PromedioEnvio.keys())
    plt.figure(figsize=(8, 5))

    bars = plt.barh(etiquetas, valores, color='skyblue')
    plt.title("Promedio de Costo de Envío por Tienda", fontweight='bold')
    plt.xlabel("Costo Promedio ($)", fontsize=12)
    plt.ylabel("Tiendas", fontsize=12)
    plt.grid(axis='x', linestyle='--', alpha=0.7)

    for bar in bars:
        width = bar.get_width()
        plt.text(width + 0.5,  # Posición X (ancho de la barra + margen)
                bar.get_y() + bar.get_height()/2,  # Posición Y (centro de la barra)
                f"${width:.2f}",  # Texto (formateado a 2 decimales)
                va='center', ha='left', fontweight='bold')

    plt.show()

def Rentabilidad():
    Tiendas = [tienda,tienda2,tienda3,tienda4]
    TiendaName = ["Tienda1","Tienda2","Tienda3","Tienda4"]
    Rentabilidad = {(TiendaName[i]):(sum(Tiendas[i]["Precio"])/sum(Tiendas[i]["Costo de envío"])) for i in range(0,4)}
    valores = list(Rentabilidad.values())
    etiquetas = list(Rentabilidad.keys())
    plt.figure(figsize=(6, 4))
    bars = plt.bar(x=etiquetas, height=valores)

    # Añadir los valores encima de cada barra
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                 f'{height:.2f}',  # Formato con 2 decimales
                 ha='center', va='bottom')

    plt.title("Relacion Precio/Costo de las tiendas")
    plt.ylabel("Rentabilidad")
    plt.ylim(0, max(valores) * 1.1)  # Dejar espacio para las etiquetas
    plt.show()

def FlujoCaja():
    Tiendas = [tienda,tienda2,tienda3,tienda4]
    TiendaName = ["Tienda1","Tienda2","Tienda3","Tienda4"]
    FlujoCaja = {(TiendaName[i]):(sum(Tiendas[i]["Precio"])/sum(Tiendas[i]["Costo de envío"])) for i in range(0,4) if (Tiendas[i]["Cantidad de cuotas"] == 1).any()}
    valores = list(FlujoCaja.values())
    etiquetas = list(FlujoCaja.keys())
    plt.figure(figsize=(6, 4))
    bars = plt.bar(x=etiquetas, height=valores)
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                 f'{height:.2f}',  # Formato con 2 decimales
                 ha='center', va='bottom')

    plt.title("Relacion Precio/Costo de las tiendas")
    plt.ylabel("Rentabilidad")
    plt.ylim(0, max(valores) * 1.1)  # Dejar espacio para las etiquetas
    plt.show()

print(f"El objetivo principal de este informe es analizar cual tienda se debe vender teniendo en cuenta los multiples factores que analizaremos a continuacion:\n\n1. Análisis de facturación")
print(f"{AnalisisFacturacion()}\n")
print(f"En el grafico anterior podemos observar que la tienda que tiene mayor facturacion es la tienda 1 y la tienda 4 fue la que menos facturo\n")
print(f"2. Ventas por categoría")
print(f"{VentasPorCategoria1()},{VentasPorCategoria2()},{VentasPorCategoria3()},{VentasPorCategoria4()}\n")
print(f"En el grafico anterior podemos observar que la categoria que mas se vende en todas las tiendas es la de muebles que esta sobre el promedio del 20% del total de\nlos productos y la que menos se venden para las tiendas 1,2 y 3 son los articulos del hogar, el producto que menos se venden en la tienda 4 son los instrumentos\nmusicales \n")
print(f"3. Calificación promedio de la tienda")
print(f"{CalificacionTienda()}\n")
print(f"La tienda con mejor calificacion es la tienda 3 y la tienda con peor calificacion es la tienda 1\n")
print("4. Productos más y menos vendidos\n")
print(f"{ProductoVendidos()}\n")
print("5. Envío promedio por tienda")
print(f"{EnvioTienda()}\n")
print(f"La tienda con mayor costo de envio es la tienda 1 y la menor costo es la tienda 4\n\n")
print(f"A pesar de que la tienda 1 tiene la mayor facturación, tiene mayor costo de envio y tiene la peor calificacion dada por los clientes, mientras que la tienda 4\ntiene menor facturacion y menor costo de envio, por ello se calculo la rentabilidad de cada tienda y los resultados fueron los siguientes:\n")
print(f"{Rentabilidad()}\n")
print(f"Observamos que la tienda mas rentable es la tienda 4 y la tienda menos rentable es la tienda 1\n")
print(f"Por ultimo revise el flujo de caja de las diferentes tiendas revisando la rentablilidad de aquellas tiendas que el pago era a 1 cuota y los resultados fueron\n los siguiente:")
print(f"{FlujoCaja()}\n")
print(f"Nuevamente la tienda mas rentable es la tienda 4 y la menos rentable es la 1\n")
print(f"Despues de realizar el analisis de los datos y los distintos factores determinantes para tomar la decision de vender una tienda, se llego a la conclusion\nque la tienda que debe ser vendida es la tienda 1 ya que a pesar de que tiene la mayor facturacion es la menos rentable por el alto costo de los envios,\ntambien es la de peor calificacion y por ultimo la que menor flujo de caja tiene.")
# Out:
# El objetivo principal de este informe es analizar cual tienda se debe vender teniendo en cuenta los multiples factores que analizaremos a continuacion:
#
# 1. Análisis de facturación
# None
#
# En el grafico anterior podemos observar que la tienda que tiene mayor facturacion es la tienda 1 y la tienda 4 fue la que menos facturo
#
# 2. Ventas por categoría
# None,None,None,None
#
# En el grafico anterior podemos observar que la categoria que mas se vende en todas las tiendas es la de muebles que esta sobre el promedio del 20% del total de
# los productos y la que menos se venden para las tiendas 1,2 y 3 son los articulos del hogar, el producto que menos se venden en la tienda 4 son los instrumentos
# musicales
#
# 3. Calificación promedio de la tienda
# None
#
# La tienda con mejor calificacion es la tienda 3 y la tienda con peor calificacion es la tienda 1
#
# 4. Productos más y menos vendidos
#
# ...
